# %% [markdown]
# # DM-1766: After
#
# Now let's try opening that file with a master version of the LSST stack, and seeing what the `Schema` looks like now:

# %%
import lsst.afw.table

catalog = lsst.afw.table.SourceCatalog.readFits("empty-v0.fits")
print catalog.schema
# Out:
# Schema(
#     (Field['L'](name="id", doc="unique ID"), Key<L>(offset=0, nElements=1)),
#     (Field['Angle'](name="coord_ra", doc="position in ra/dec"), Key<Angle>(offset=8, nElements=1)),
#     (Field['Angle'](name="coord_dec", doc="position in ra/dec"), Key<Angle>(offset=16, nElements=1)),
#     (Field['L'](name="parent", doc="unique ID of parent source"), Key<L>(offset=24, nElements=1)),
#     (Field['Flag'](name="flag_negative", doc="set if source was detected as significantly negative"), Key['Flag'](offset=32, bit=0)),
#     (Field['I'](name="deblend_nchild", doc="Number of children this object has (defaults to 0)"), Key<I>(offset=40, nElements=1)),
#     (Field['Flag'](name="deblend_deblended-as-psf", doc="Deblender thought this source looked like a PSF"), Key['Flag'](offset=32, bit=1)),
#     (Field['D'](name="deblend_psf-center_x", doc="If deblended-as-psf, the PSF centroid"), Key<D>(offset=48, nElements=1)),
#     (Field['D'](name="deblend_psf-center_y", doc="If deblended-as-psf, the PSF centroid"), Key<D>(offset=56, nElements=1)),
#     (Field['D'](name="deblend_psf-flux", doc="If deblended-as-psf, the PSF flux"), Key<D>(offset=64, nElements=1)),
#     (Field['Flag'](name="deblend_too-many-peaks", doc="Source had too many peaks; only the brightest were included"), Key['Flag'](offset=32, bit=2)),
#     (Field['Flag'](name="deblend_parent-too-big", doc="Parent footprint covered too many pixels"), Key['Flag'](offset=32, bit=3)),
#     (Field['Flag'](name="deblend_skipped", doc="Deblender skipped this source"), Key['Flag'](offset=32, bit=4)),
#     (Field['Flag'](name="deblend_ramped_template", doc="This source was near an image edge and the deblender used "ramp" edge-handling."), Key['Flag'](offset=32, bit=5)),
#     (Field['Flag'](name="deblend_patched_template", doc="This source was near an image edge and the deblender used "patched" edge-handling."), Key['Flag'](offset=32, bit=6)),
#     (Field['Flag'](name="deblend_has_stray_flux", doc="This source was assigned some stray flux"), Key['Flag'](offset=32, bit=7)),
#     (Field['Flag'](name="flag_badcentroid", doc="the centroid algorithm used to feed centers to other algorithms failed"), Key['Flag'](offset=32, bit=8)),
#     (Field['D'](name="centroid_sdss_x", doc="SDSS-algorithm centroid measurement", units="pixels"), Key<D>(offset=72, nElements=1)),
#     (Field['D'](name="centroid_sdss_y", doc="SDSS-algorithm centroid measurement", units="pixels"), Key<D>(offset=80, nElements=1)),
#     (Field['F'](name="centroid_sdss_err_xSigma", doc="1-sigma uncertainty on x", units="pixels^2"), Key<F>(offset=88, nElements=1)),
#     (Field['F'](name="centroid_sdss_err_ySigma", doc="1-sigma uncertainty on y", units="pixels^2"), Key<F>(offset=92, nElements=1)),
#     (Field['F'](name="centroid_sdss_err_x_y_Cov", doc="uncertainty covariance between x and y", units="pixels^2^2"), Key<F>(offset=96, nElements=1)),
#     (Field['Flag'](name="centroid_sdss_flag", doc="set if the centroid.sdss measurement did not fully succeed"), Key['Flag'](offset=32, bit=9)),
#     (Field['D'](name="centroid_naive_x", doc="unweighted 3x3 first moment centroid", units="pixels"), Key<D>(offset=104, nElements=1)),
#     (Field['D'](name="centroid_naive_y", doc="unweighted 3x3 first moment centroid", units="pixels"), Key<D>(offset=112, nElements=1)),
#     (Field['F'](name="centroid_naive_err_xSigma", doc="1-sigma uncertainty on x", units="pixels^2"), Key<F>(offset=120, nElements=1)),
#     (Field['F'](name="centroid_naive_err_ySigma", doc="1-sigma uncertainty on y", units="pixels^2"), Key<F>(offset=124, nElements=1)),
#     (Field['F'](name="centroid_naive_err_x_y_Cov", doc="uncertainty covariance between x and y", units="pixels^2^2"), Key<F>(offset=128, nElements=1)),
#     (Field['Flag'](name="centroid_naive_flag", doc="set if the centroid.naive measurement did not fully succeed"), Key['Flag'](offset=32, bit=10)),
#     (Field['Flag'](name="flag_pixel_edge", doc="source is in region masked EDGE or NO_DATA"), Key['Flag'](offset=32, bit=11)),
#     (Field['Flag'](name="flag_pixel_interpolated_any", doc="source''''s footprint includes interpolated pixels"), Key['Flag'](offset=32, bit=12)),
#     (Field['Flag'](name="flag_pixel_interpolated_center", doc="source''''s center is close to interpolated pixels"), Key['Flag'](offset=32, bit=13)),
#     (Field['Flag'](name="flag_pixel_saturated_any", doc="source''''s footprint includes saturated pixels"), Key['Flag'](offset=32, bit=14)),
#     (Field['Flag'](name="flag_pixel_saturated_center", doc="source''''s center is close to saturated pixels"), Key['Flag'](offset=32, bit=15)),
#     (Field['Flag'](name="flag_pixel_cr_any", doc="source''''s footprint includes suspected CR pixels"), Key['Flag'](offset=32, bit=16)),
#     (Field['Flag'](name="flag_pixel_cr_center", doc="source''''s center is close to suspected CR pixels"), Key['Flag'](offset=32, bit=17)),
#     (Field['Flag'](name="flag_pixel_bad", doc="source is in region labeled BAD"), Key['Flag'](offset=32, bit=18)),
#     (Field['Flag'](name="flag_pixel_suspect_any", doc="source''''s footprint includes suspect pixels"), Key['Flag'](offset=32, bit=19)),
#     (Field['Flag'](name="flag_pixel_suspect_center", doc="source''''s center is close to suspect pixels"), Key['Flag'](offset=32, bit=20)),
#     (Field['Flag'](name="flag_pixel_CLIPPED_center", doc="source center is close to CLIPPED pixels"), Key['Flag'](offset=32, bit=21)),
#     (Field['Flag'](name="flag_pixel_CLIPPED_any", doc="source footprint includes CLIPPED pixels"), Key['Flag'](offset=32, bit=22)),
#     (Field['D'](name="shape_hsm_moments_xx", doc="source adaptive moments from HSM", units="pixels^2"), Key<D>(offset=136, nElements=1)),
#     (Field['D'](name="shape_hsm_moments_yy", doc="source adaptive moments from HSM", units="pixels^2"), Key<D>(offset=144, nElements=1)),
#     (Field['D'](name="shape_hsm_moments_xy", doc="source adaptive moments from HSM", units="pixels^2"), Key<D>(offset=152, nElements=1)),
#     (Field['F'](name="shape_hsm_moments_err_xxSigma", doc="1-sigma uncertainty on xx", units="pixels^4"), Key<F>(offset=160, nElements=1)),
#     (Field['F'](name="shape_hsm_moments_err_yySigma", doc="1-sigma uncertainty on yy", units="pixels^4"), Key<F>(offset=164, nElements=1)),
#     (Field['F'](name="shape_hsm_moments_err_xySigma", doc="1-sigma uncertainty on xy", units="pixels^4"), Key<F>(offset=168, nElements=1)),
#     (Field['F'](name="shape_hsm_moments_err_xx_yy_Cov", doc="uncertainty covariance between xx and yy", units="pixels^4^2"), Key<F>(offset=172, nElements=1)),
#     (Field['F'](name="shape_hsm_moments_err_xx_xy_Cov", doc="uncertainty covariance between xx and xy", units="pixels^4^2"), Key<F>(offset=176, nElements=1)),
#     (Field['F'](name="shape_hsm_moments_err_yy_xy_Cov", doc="uncertainty covariance between yy and xy", units="pixels^4^2"), Key<F>(offset=180, nElements=1)),
#     (Field['Flag'](name="shape_hsm_moments_flag", doc="set if the shape.hsm.moments measurement failed"), Key['Flag'](offset=32, bit=23)),
#     (Field['D'](name="shape_hsm_moments_centroid_x", doc="centroid measured with HSM adaptive moment shape algorithm", units="pixels"), Key<D>(offset=184, nElements=1)),
#     (Field['D'](name="shape_hsm_moments_centroid_y", doc="centroid measured with HSM adaptive moment shape algorithm", units="pixels"), Key<D>(offset=192, nElements=1)),
#     (Field['F'](name="shape_hsm_moments_centroid_err_xSigma", doc="1-sigma uncertainty on x", units="pixels^2"), Key<F>(offset=200, nElements=1)),
#     (Field['F'](name="shape_hsm_moments_centroid_err_ySigma", doc="1-sigma uncertainty on y", units="pixels^2"), Key<F>(offset=204, nElements=1)),
#     (Field['F'](name="shape_hsm_moments_centroid_err_x_y_Cov", doc="uncertainty covariance between x and y", units="pixels^2^2"), Key<F>(offset=208, nElements=1)),
#     (Field['Flag'](name="shape_hsm_moments_centroid_flag", doc="set if the shape.hsm.moments.centroid measurement did not fully succeed"), Key['Flag'](offset=32, bit=24)),
#     (Field['D'](name="shape_hsm_psfMoments_xx", doc="PSF adaptive moments from HSM", units="pixels^2"), Key<D>(offset=216, nElements=1)),
#     (Field['D'](name="shape_hsm_psfMoments_yy", doc="PSF adaptive moments from HSM", units="pixels^2"), Key<D>(offset=224, nElements=1)),
#     (Field['D'](name="shape_hsm_psfMoments_xy", doc="PSF adaptive moments from HSM", units="pixels^2"), Key<D>(offset=232, nElements=1)),
#     (Field['F'](name="shape_hsm_psfMoments_err_xxSigma", doc="1-sigma uncertainty on xx", units="pixels^4"), Key<F>(offset=240, nElements=1)),
#     (Field['F'](name="shape_hsm_psfMoments_err_yySigma", doc="1-sigma uncertainty on yy", units="pixels^4"), Key<F>(offset=244, nElements=1)),
#     (Field['F'](name="shape_hsm_psfMoments_err_xySigma", doc="1-sigma uncertainty on xy", units="pixels^4"), Key<F>(offset=248, nElements=1)),
#     (Field['F'](name="shape_hsm_psfMoments_err_xx_yy_Cov", doc="uncertainty covariance between xx and yy", units="pixels^4^2"), Key<F>(offset=252, nElements=1)),
#     (Field['F'](name="shape_hsm_psfMoments_err_xx_xy_Cov", doc="uncertainty covariance between xx and xy", units="pixels^4^2"), Key<F>(offset=256, nElements=1)),
#     (Field['F'](name="shape_hsm_psfMoments_err_yy_xy_Cov", doc="uncertainty covariance between yy and xy", units="pixels^4^2"), Key<F>(offset=260, nElements=1)),
#     (Field['Flag'](name="shape_hsm_psfMoments_flag", doc="set if the shape.hsm.psfMoments measurement failed"), Key['Flag'](offset=32, bit=25)),
#     (Field['D'](name="shape_hsm_psfMoments_centroid_x", doc="centroid measured with HSM adaptive moment shape algorithm", units="pixels"), Key<D>(offset=264, nElements=1)),
#     (Field['D'](name="shape_hsm_psfMoments_centroid_y", doc="centroid measured with HSM adaptive moment shape algorithm", units="pixels"), Key<D>(offset=272, nElements=1)),
#     (Field['F'](name="shape_hsm_psfMoments_centroid_err_xSigma", doc="1-sigma uncertainty on x", units="pixels^2"), Key<F>(offset=280, nElements=1)),
#     (Field['F'](name="shape_hsm_psfMoments_centroid_err_ySigma", doc="1-sigma uncertainty on y", units="pixels^2"), Key<F>(offset=284, nElements=1)),
#     (Field['F'](name="shape_hsm_psfMoments_centroid_err_x_y_Cov", doc="uncertainty covariance between x and y", units="pixels^2^2"), Key<F>(offset=288, nElements=1)),
#     (Field['Flag'](name="shape_hsm_psfMoments_centroid_flag", doc="set if the shape.hsm.psfMoments.centroid measurement did not fully succeed"), Key['Flag'](offset=32, bit=26)),
#     (Field['D'](name="shape_hsm_regauss_e1", doc="PSF-corrected ellipticity using Hirata & Seljak (2003) ''''regaussianization"), Key<D>(offset=296, nElements=1)),
#     (Field['D'](name="shape_hsm_regauss_e2", doc="PSF-corrected ellipticity using Hirata & Seljak (2003) ''''regaussianization"), Key<D>(offset=304, nElements=1)),
#     (Field['D'](name="shape_hsm_regauss_sigma", doc="PSF-corrected ellipticity using Hirata & Seljak (2003) ''''regaussianization"), Key<D>(offset=312, nElements=1)),
#     (Field['D'](name="shape_hsm_regauss_resolution", doc="resolution factor (0=unresolved, 1=resolved)"), Key<D>(offset=320, nElements=1)),
#     (Field['Flag'](name="shape_hsm_regauss_flag", doc="set if measurement failed in any way"), Key['Flag'](offset=32, bit=27)),
#     (Field['D'](name="shape_sdss_xx", doc="shape measured with SDSS adaptive moment algorithm", units="pixels^2"), Key<D>(offset=328, nElements=1)),
#     (Field['D'](name="shape_sdss_yy", doc="shape measured with SDSS adaptive moment algorithm", units="pixels^2"), Key<D>(offset=336, nElements=1)),
#     (Field['D'](name="shape_sdss_xy", doc="shape measured with SDSS adaptive moment algorithm", units="pixels^2"), Key<D>(offset=344, nElements=1)),
#     (Field['F'](name="shape_sdss_err_xxSigma", doc="1-sigma uncertainty on xx", units="pixels^4"), Key<F>(offset=352, nElements=1)),
#     (Field['F'](name="shape_sdss_err_yySigma", doc="1-sigma uncertainty on yy", units="pixels^4"), Key<F>(offset=356, nElements=1)),
#     (Field['F'](name="shape_sdss_err_xySigma", doc="1-sigma uncertainty on xy", units="pixels^4"), Key<F>(offset=360, nElements=1)),
#     (Field['F'](name="shape_sdss_err_xx_yy_Cov", doc="uncertainty covariance between xx and yy", units="pixels^4^2"), Key<F>(offset=364, nElements=1)),
#     (Field['F'](name="shape_sdss_err_xx_xy_Cov", doc="uncertainty covariance between xx and xy", units="pixels^4^2"), Key<F>(offset=368, nElements=1)),
#     (Field['F'](name="shape_sdss_err_yy_xy_Cov", doc="uncertainty covariance between yy and xy", units="pixels^4^2"), Key<F>(offset=372, nElements=1)),
#     (Field['Flag'](name="shape_sdss_flag", doc="set if the shape.sdss measurement failed"), Key['Flag'](offset=32, bit=28)),
#     (Field['D'](name="shape_sdss_centroid_x", doc="centroid measured with SDSS adaptive moment shape algorithm", units="pixels"), Key<D>(offset=376, nElements=1)),
#     (Field['D'](name="shape_sdss_centroid_y", doc="centroid measured with SDSS adaptive moment shape algorithm", units="pixels"), Key<D>(offset=384, nElements=1)),
#     (Field['F'](name="shape_sdss_centroid_err_xSigma", doc="1-sigma uncertainty on x", units="pixels^2"), Key<F>(offset=392, nElements=1)),
#     (Field['F'](name="shape_sdss_centroid_err_ySigma", doc="1-sigma uncertainty on y", units="pixels^2"), Key<F>(offset=396, nElements=1)),
#     (Field['F'](name="shape_sdss_centroid_err_x_y_Cov", doc="uncertainty covariance between x and y", units="pixels^2^2"), Key<F>(offset=400, nElements=1)),
#     (Field['Flag'](name="shape_sdss_centroid_flag", doc="set if the shape.sdss.centroid measurement did not fully succeed"), Key['Flag'](offset=32, bit=29)),
#     (Field['Flag'](name="shape_sdss_flag_unweightedbad", doc="even the unweighted moments were bad"), Key['Flag'](offset=32, bit=30)),
#     (Field['Flag'](name="shape_sdss_flag_unweighted", doc="adaptive moments failed; fall back to unweighted moments"), Key['Flag'](offset=32, bit=31)),
#     (Field['Flag'](name="shape_sdss_flag_shift", doc="centroid shifted while estimating adaptive moments"), Key['Flag'](offset=32, bit=32)),
#     (Field['Flag'](name="shape_sdss_flag_maxiter", doc="too many iterations for adaptive moments"), Key['Flag'](offset=32, bit=33)),
#     (Field['D'](name="shape_sdss_psf_xx", doc="adaptive moments of the PSF model at the position of this object", units="pixels^2"), Key<D>(offset=408, nElements=1)),
#     (Field['D'](name="shape_sdss_psf_yy", doc="adaptive moments of the PSF model at the position of this object", units="pixels^2"), Key<D>(offset=416, nElements=1)),
#     (Field['D'](name="shape_sdss_psf_xy", doc="adaptive moments of the PSF model at the position of this object", units="pixels^2"), Key<D>(offset=424, nElements=1)),
#     (Field['Flag'](name="shape_sdss_flag_psf", doc="failure in measuring PSF model shape"), Key['Flag'](offset=32, bit=34)),
#     (Field['ArrayD'](name="flux_aperture", doc="sum of pixels in apertures", units="dn", size=10), Key<ArrayD>(offset=432, nElements=10)),
#     (Field['ArrayD'](name="flux_aperture_err", doc="uncertainty for flux.aperture", units="dn", size=10), Key<ArrayD>(offset=512, nElements=10)),
#     (Field['ArrayI'](name="flux_aperture_nInterpolatedPixel", doc="Number of interpolated pixels in the aperture", units="int", size=10), Key<ArrayI>(offset=592, nElements=10)),
#     (Field['I'](name="flux_aperture_nProfile", doc="pixels", units="Number of points in radial profile successfully measured"), Key<I>(offset=632, nElements=1)),
#     (Field['Flag'](name="flux_aperture_flag", doc="success flag for flux.aperture"), Key['Flag'](offset=32, bit=35)),
#     (Field['D'](name="flux_gaussian", doc="linear fit to an elliptical Gaussian with shape parameters set by adaptive moments", units="dn"), Key<D>(offset=640, nElements=1)),
#     (Field['D'](name="flux_gaussian_err", doc="uncertainty for flux.gaussian", units="dn"), Key<D>(offset=648, nElements=1)),
#     (Field['Flag'](name="flux_gaussian_flag", doc="set if the flux.gaussian measurement failed"), Key['Flag'](offset=32, bit=36)),
#     (Field['D'](name="flux_kron", doc="Kron photometry: photometry with aperture set to some multiple of <radius>determined within some multiple of the source size", units="dn"), Key<D>(offset=656, nElements=1)),
#     (Field['D'](name="flux_kron_err", doc="uncertainty for flux.kron", units="dn"), Key<D>(offset=664, nElements=1)),
#     (Field['Flag'](name="flux_kron_flag", doc="set if the flux.kron measurement failed"), Key['Flag'](offset=32, bit=37)),
#     (Field['F'](name="flux_kron_radius", doc="Kron radius (sqrt(a*b))"), Key<F>(offset=672, nElements=1)),
#     (Field['F'](name="flux_kron_radiusForRadius", doc="Radius used to estimate <radius> (sqrt(a*b))"), Key<F>(offset=676, nElements=1)),
#     (Field['Flag'](name="flux_kron_flag_edge", doc="Inaccurate measurement due to image edge"), Key['Flag'](offset=32, bit=38)),
#     (Field['Flag'](name="flux_kron_flag_radius", doc="Bad Kron radius"), Key['Flag'](offset=32, bit=39)),
#     (Field['Flag'](name="flux_kron_flag_smallRadius", doc="Measured Kron radius was smaller than that of the PSF"), Key['Flag'](offset=32, bit=40)),
#     (Field['Flag'](name="flux_kron_flag_usedMinimumRadius", doc="Used the minimum radius for the Kron aperture"), Key['Flag'](offset=32, bit=41)),
#     (Field['Flag'](name="flux_kron_flag_usedPsfRadius", doc="Used the PSF Kron radius for the Kron aperture"), Key['Flag'](offset=32, bit=42)),
#     (Field['F'](name="flux_kron_psfRadius", doc="Radius of PSF"), Key<F>(offset=680, nElements=1)),
#     (Field['Flag'](name="flux_kron_flag_badShape", doc="Shape for measuring Kron radius is bad; used PSF shape"), Key['Flag'](offset=32, bit=43)),
#     (Field['D'](name="flux_naive", doc="simple sum over pixels in a circular aperture", units="dn"), Key<D>(offset=688, nElements=1)),
#     (Field['D'](name="flux_naive_err", doc="uncertainty for flux.naive", units="dn"), Key<D>(offset=696, nElements=1)),
#     (Field['Flag'](name="flux_naive_flag", doc="set if the flux.naive measurement failed"), Key['Flag'](offset=32, bit=44)),
#     (Field['D'](name="flux_psf", doc="flux measured by a fit to the PSF model", units="dn"), Key<D>(offset=704, nElements=1)),
#     (Field['D'](name="flux_psf_err", doc="uncertainty for flux.psf", units="dn"), Key<D>(offset=712, nElements=1)),
#     (Field['Flag'](name="flux_psf_flag", doc="set if the flux.psf measurement failed"), Key['Flag'](offset=32, bit=45)),
#     (Field['D'](name="flux_sinc", doc="elliptical aperture photometry using sinc interpolation", units="dn"), Key<D>(offset=720, nElements=1)),
#     (Field['D'](name="flux_sinc_err", doc="uncertainty for flux.sinc", units="dn"), Key<D>(offset=728, nElements=1)),
#     (Field['Flag'](name="flux_sinc_flag", doc="set if the flux.sinc measurement failed"), Key['Flag'](offset=32, bit=46)),
#     (Field['ArrayF'](name="multishapelet_psf_inner", doc="Gauss-Hermite coefficients of the inner expansion (see lsst.shapelet package)", size=6), Key<ArrayF>(offset=736, nElements=6)),
#     (Field['ArrayF'](name="multishapelet_psf_outer", doc="Gauss-Hermite coefficients of the outer expansion (see lsst.shapelet package)", size=6), Key<ArrayF>(offset=760, nElements=6)),
#     (Field['D'](name="multishapelet_psf_ellipse_xx", doc="Ellipse corresponding to the inner expansion", units="pixels^2"), Key<D>(offset=784, nElements=1)),
#     (Field['D'](name="multishapelet_psf_ellipse_yy", doc="Ellipse corresponding to the inner expansion", units="pixels^2"), Key<D>(offset=792, nElements=1)),
#     (Field['D'](name="multishapelet_psf_ellipse_xy", doc="Ellipse corresponding to the inner expansion", units="pixels^2"), Key<D>(offset=800, nElements=1)),
#     (Field['F'](name="multishapelet_psf_chisq", doc="Reduced chi^2 of the final shapelet fit"), Key<F>(offset=808, nElements=1)),
#     (Field['F'](name="multishapelet_psf_integral", doc="Integral of the shapelet PSF model to infinite radius"), Key<F>(offset=812, nElements=1)),
#     (Field['Flag'](name="multishapelet_psf_flag", doc="set if the multi-shapelet PSF fit was unsuccessful in any way"), Key['Flag'](offset=32, bit=47)),
#     (Field['Flag'](name="multishapelet_psf_flag_maxiter", doc="set if the optimizer ran into the maximum number of iterations limit"), Key['Flag'](offset=32, bit=48)),
#     (Field['Flag'](name="multishapelet_psf_flag_tinystep", doc="set if the optimizer step or trust region got so small no progress could be made"), Key['Flag'](offset=32, bit=49)),
#     (Field['Flag'](name="multishapelet_psf_flag_constraint_r", doc="set if the best-fit radius was the minimum allowed by the constraint"), Key['Flag'](offset=32, bit=50)),
#     (Field['Flag'](name="multishapelet_psf_flag_constraint_q", doc="set if the best-fit axis ratio (b/a) was the minimum allowed by the constraint"), Key['Flag'](offset=32, bit=51)),
#     (Field['D'](name="cmodel_initial_flux", doc="flux from the initial fit", units="dn"), Key<D>(offset=816, nElements=1)),
#     (Field['D'](name="cmodel_initial_flux_err", doc="uncertainty for cmodel.initial.flux", units="dn"), Key<D>(offset=824, nElements=1)),
#     (Field['Flag'](name="cmodel_initial_flux_flag", doc="set if the cmodel.initial.flux measurement failed"), Key['Flag'](offset=32, bit=52)),
#     (Field['D'](name="cmodel_initial_ellipse_xx", doc="effective radius ellipse from the initial fit", units="pixels^2"), Key<D>(offset=832, nElements=1)),
#     (Field['D'](name="cmodel_initial_ellipse_yy", doc="effective radius ellipse from the initial fit", units="pixels^2"), Key<D>(offset=840, nElements=1)),
#     (Field['D'](name="cmodel_initial_ellipse_xy", doc="effective radius ellipse from the initial fit", units="pixels^2"), Key<D>(offset=848, nElements=1)),
#     (Field['D'](name="cmodel_initial_objective", doc="-ln(likelihood*prior) at best-fit point for the initial fit"), Key<D>(offset=856, nElements=1)),
#     (Field['ArrayD'](name="cmodel_initial_nonlinear", doc="nonlinear parameters for the initial fit", size=3), Key<ArrayD>(offset=864, nElements=3)),
#     (Field['ArrayD'](name="cmodel_initial_fixed", doc="fixed parameters for the initial fit", size=2), Key<ArrayD>(offset=888, nElements=2)),
#     (Field['Flag'](name="cmodel_initial_flag_trSmall", doc="the optimizer converged because the trust radius became too small; this is a less-secure result than when the gradient is below the threshold, but usually not a problem"), Key['Flag'](offset=32, bit=53)),
#     (Field['Flag'](name="cmodel_initial_flag_maxIter", doc="the optimizer hit the maximum number of iterations and did not converge"), Key['Flag'](offset=32, bit=54)),
#     (Field['Flag'](name="cmodel_initial_flag_numericError", doc="numerical underflow or overflow in model evaluation; usually this means the prior was insufficient to regularize the fit"), Key['Flag'](offset=32, bit=55)),
#     (Field['I'](name="cmodel_initial_nIter", doc="Number of total iterations in stage"), Key<I>(offset=904, nElements=1)),
#     (Field['D'](name="cmodel_initial_time", doc="Time spent in stage", units="seconds"), Key<D>(offset=912, nElements=1)),
#     (Field['D'](name="cmodel_exp_flux", doc="flux from the exponential fit", units="dn"), Key<D>(offset=920, nElements=1)),
#     (Field['D'](name="cmodel_exp_flux_err", doc="uncertainty for cmodel.exp.flux", units="dn"), Key<D>(offset=928, nElements=1)),
#     (Field['Flag'](name="cmodel_exp_flux_flag", doc="set if the cmodel.exp.flux measurement failed"), Key['Flag'](offset=32, bit=56)),
#     (Field['D'](name="cmodel_exp_ellipse_xx", doc="effective radius ellipse from the exponential fit", units="pixels^2"), Key<D>(offset=936, nElements=1)),
#     (Field['D'](name="cmodel_exp_ellipse_yy", doc="effective radius ellipse from the exponential fit", units="pixels^2"), Key<D>(offset=944, nElements=1)),
#     (Field['D'](name="cmodel_exp_ellipse_xy", doc="effective radius ellipse from the exponential fit", units="pixels^2"), Key<D>(offset=952, nElements=1)),
#     (Field['D'](name="cmodel_exp_objective", doc="-ln(likelihood*prior) at best-fit point for the exponential fit"), Key<D>(offset=960, nElements=1)),
#     (Field['ArrayD'](name="cmodel_exp_nonlinear", doc="nonlinear parameters for the exponential fit", size=3), Key<ArrayD>(offset=968, nElements=3)),
#     (Field['ArrayD'](name="cmodel_exp_fixed", doc="fixed parameters for the exponential fit", size=2), Key<ArrayD>(offset=992, nElements=2)),
#     (Field['Flag'](name="cmodel_exp_flag_trSmall", doc="the optimizer converged because the trust radius became too small; this is a less-secure result than when the gradient is below the threshold, but usually not a problem"), Key['Flag'](offset=32, bit=57)),
#     (Field['Flag'](name="cmodel_exp_flag_maxIter", doc="the optimizer hit the maximum number of iterations and did not converge"), Key['Flag'](offset=32, bit=58)),
#     (Field['Flag'](name="cmodel_exp_flag_numericError", doc="numerical underflow or overflow in model evaluation; usually this means the prior was insufficient to regularize the fit"), Key['Flag'](offset=32, bit=59)),
#     (Field['I'](name="cmodel_exp_nIter", doc="Number of total iterations in stage"), Key<I>(offset=1008, nElements=1)),
#     (Field['D'](name="cmodel_exp_time", doc="Time spent in stage", units="seconds"), Key<D>(offset=1016, nElements=1)),
#     (Field['D'](name="cmodel_dev_flux", doc="flux from the de Vaucouleur fit", units="dn"), Key<D>(offset=1024, nElements=1)),
#     (Field['D'](name="cmodel_dev_flux_err", doc="uncertainty for cmodel.dev.flux", units="dn"), Key<D>(offset=1032, nElements=1)),
#     (Field['Flag'](name="cmodel_dev_flux_flag", doc="set if the cmodel.dev.flux measurement failed"), Key['Flag'](offset=32, bit=60)),
#     (Field['D'](name="cmodel_dev_ellipse_xx", doc="effective radius ellipse from the de Vaucouleur fit", units="pixels^2"), Key<D>(offset=1040, nElements=1)),
#     (Field['D'](name="cmodel_dev_ellipse_yy", doc="effective radius ellipse from the de Vaucouleur fit", units="pixels^2"), Key<D>(offset=1048, nElements=1)),
#     (Field['D'](name="cmodel_dev_ellipse_xy", doc="effective radius ellipse from the de Vaucouleur fit", units="pixels^2"), Key<D>(offset=1056, nElements=1)),
#     (Field['D'](name="cmodel_dev_objective", doc="-ln(likelihood*prior) at best-fit point for the de Vaucouleur fit"), Key<D>(offset=1064, nElements=1)),
#     (Field['ArrayD'](name="cmodel_dev_nonlinear", doc="nonlinear parameters for the de Vaucouleur fit", size=3), Key<ArrayD>(offset=1072, nElements=3)),
#     (Field['ArrayD'](name="cmodel_dev_fixed", doc="fixed parameters for the de Vaucouleur fit", size=2), Key<ArrayD>(offset=1096, nElements=2)),
#     (Field['Flag'](name="cmodel_dev_flag_trSmall", doc="the optimizer converged because the trust radius became too small; this is a less-secure result than when the gradient is below the threshold, but usually not a problem"), Key['Flag'](offset=32, bit=61)),
#     (Field['Flag'](name="cmodel_dev_flag_maxIter", doc="the optimizer hit the maximum number of iterations and did not converge"), Key['Flag'](offset=32, bit=62)),
#     (Field['Flag'](name="cmodel_dev_flag_numericError", doc="numerical underflow or overflow in model evaluation; usually this means the prior was insufficient to regularize the fit"), Key['Flag'](offset=32, bit=63)),
#     (Field['I'](name="cmodel_dev_nIter", doc="Number of total iterations in stage"), Key<I>(offset=1112, nElements=1)),
#     (Field['D'](name="cmodel_dev_time", doc="Time spent in stage", units="seconds"), Key<D>(offset=1120, nElements=1)),
#     (Field['D'](name="cmodel_center_x", doc="center position used in CModel fit", units="pixels"), Key<D>(offset=1128, nElements=1)),
#     (Field['D'](name="cmodel_center_y", doc="center position used in CModel fit", units="pixels"), Key<D>(offset=1136, nElements=1)),
#     (Field['D'](name="cmodel_flux", doc="flux from the final cmodel fit", units="dn"), Key<D>(offset=1144, nElements=1)),
#     (Field['D'](name="cmodel_flux_err", doc="uncertainty for cmodel.flux", units="dn"), Key<D>(offset=1152, nElements=1)),
#     (Field['Flag'](name="cmodel_flux_flag", doc="set if the cmodel.flux measurement failed"), Key['Flag'](offset=1160, bit=0)),
#     (Field['D'](name="cmodel_fracDev", doc="fraction of flux in de Vaucouleur component"), Key<D>(offset=1168, nElements=1)),
#     (Field['D'](name="cmodel_objective", doc="-ln(likelihood) (chi^2) in cmodel fit"), Key<D>(offset=1176, nElements=1)),
#     (Field['Flag'](name="cmodel_flag_maxArea", doc="number of pixels in fit region exceeded the region.maxArea value (usually due to bad moments)"), Key['Flag'](offset=1160, bit=1)),
#     (Field['Flag'](name="cmodel_flag_maxBadPixelFraction", doc="the fraction of bad/clipped pixels in the fit region exceeded region.maxBadPixelFraction"), Key['Flag'](offset=1160, bit=2)),
#     (Field['Flag'](name="cmodel_flag_noShape", doc="the shape slot needed to initialize the parameters failed or was not defined"), Key['Flag'](offset=1160, bit=3)),
#     (Field['Flag'](name="cmodel_flag_noPsf", doc="the multishapelet fit to the PSF model did not succeed"), Key['Flag'](offset=1160, bit=4)),
#     (Field['Flag'](name="cmodel_flag_noWcs", doc="input exposure has no world coordinate system information"), Key['Flag'](offset=1160, bit=5)),
#     (Field['Flag'](name="cmodel_flag_noCalib", doc="input exposure has no photometric calibration information"), Key['Flag'](offset=1160, bit=6)),
#     (Field['D'](name="cmodel_dev_flux_apcorr", doc="aperture correction applied to cmodel.dev.flux"), Key<D>(offset=1184, nElements=1)),
#     (Field['D'](name="cmodel_dev_flux_apcorr_err", doc="error on aperture correction applied to cmodel.dev.flux"), Key<D>(offset=1192, nElements=1)),
#     (Field['Flag'](name="cmodel_dev_flux_flag_apcorr", doc="set if aperture correction lookup failed"), Key['Flag'](offset=1160, bit=7)),
#     (Field['D'](name="cmodel_exp_flux_apcorr", doc="aperture correction applied to cmodel.exp.flux"), Key<D>(offset=1200, nElements=1)),
#     (Field['D'](name="cmodel_exp_flux_apcorr_err", doc="error on aperture correction applied to cmodel.exp.flux"), Key<D>(offset=1208, nElements=1)),
#     (Field['Flag'](name="cmodel_exp_flux_flag_apcorr", doc="set if aperture correction lookup failed"), Key['Flag'](offset=1160, bit=8)),
#     (Field['D'](name="cmodel_flux_apcorr", doc="aperture correction applied to cmodel.flux"), Key<D>(offset=1216, nElements=1)),
#     (Field['D'](name="cmodel_flux_apcorr_err", doc="error on aperture correction applied to cmodel.flux"), Key<D>(offset=1224, nElements=1)),
#     (Field['Flag'](name="cmodel_flux_flag_apcorr", doc="set if aperture correction lookup failed"), Key['Flag'](offset=1160, bit=9)),
#     (Field['D'](name="flux_gaussian_apcorr", doc="aperture correction applied to flux.gaussian"), Key<D>(offset=1232, nElements=1)),
#     (Field['D'](name="flux_gaussian_apcorr_err", doc="error on aperture correction applied to flux.gaussian"), Key<D>(offset=1240, nElements=1)),
#     (Field['Flag'](name="flux_gaussian_flag_apcorr", doc="set if aperture correction lookup failed"), Key['Flag'](offset=1160, bit=10)),
#     (Field['D'](name="flux_kron_apcorr", doc="aperture correction applied to flux.kron"), Key<D>(offset=1248, nElements=1)),
#     (Field['D'](name="flux_kron_apcorr_err", doc="error on aperture correction applied to flux.kron"), Key<D>(offset=1256, nElements=1)),
#     (Field['Flag'](name="flux_kron_flag_apcorr", doc="set if aperture correction lookup failed"), Key['Flag'](offset=1160, bit=11)),
#     (Field['D'](name="flux_psf_apcorr", doc="aperture correction applied to flux.psf"), Key<D>(offset=1264, nElements=1)),
#     (Field['D'](name="flux_psf_apcorr_err", doc="error on aperture correction applied to flux.psf"), Key<D>(offset=1272, nElements=1)),
#     (Field['Flag'](name="flux_psf_flag_apcorr", doc="set if aperture correction lookup failed"), Key['Flag'](offset=1160, bit=12)),
#     (Field['D'](name="classification_extendedness", doc="probability of being extended"), Key<D>(offset=1280, nElements=1)),
#     (Field['Flag'](name="detect_is-patch-inner", doc="true if source is in the inner region of a coadd patch"), Key['Flag'](offset=1160, bit=13)),
#     (Field['Flag'](name="detect_is-tract-inner", doc="true if source is in the inner region of a coadd tract"), Key['Flag'](offset=1160, bit=14)),
#     (Field['Flag'](name="detect_is-primary", doc="true if source has no children and is in the inner region of a coadd patch and is in the inner region of a coadd tract"), Key['Flag'](offset=1160, bit=15)),
#     (Field['Flag'](name="calib_psf_candidate", doc="Propagated from visits"), Key['Flag'](offset=1160, bit=16)),
#     (Field['Flag'](name="calib_psf_used", doc="Propagated from visits"), Key['Flag'](offset=1160, bit=17)),
#     (Field['D'](name="centroid_distorted_x", doc="centroid distorted for astrometry solver"), Key<D>(offset=1288, nElements=1)),
#     (Field['D'](name="centroid_distorted_y", doc="centroid distorted for astrometry solver"), Key<D>(offset=1296, nElements=1)),
#     'centroid_naive_flags'->'centroid_naive_flag'
#     'centroid_naive_xSigma'->'centroid_naive_err_xSigma'
#     'centroid_naive_x_y_Cov'->'centroid_naive_err_x_y_Cov'
#     'centroid_naive_ySigma'->'centroid_naive_err_ySigma'
#     'centroid_sdss_flags'->'centroid_sdss_flag'
#     'centroid_sdss_xSigma'->'centroid_sdss_err_xSigma'
#     'centroid_sdss_x_y_Cov'->'centroid_sdss_err_x_y_Cov'
#     'centroid_sdss_ySigma'->'centroid_sdss_err_ySigma'
#     'cmodel_dev_flags'->'cmodel_dev_flag'
#     'cmodel_dev_flux_apcorr_flux'->'cmodel_dev_flux_apcorr'
#     'cmodel_dev_flux_apcorr_fluxSigma'->'cmodel_dev_flux_apcorr_err'
#     'cmodel_dev_flux_flags'->'cmodel_dev_flux_flag'
#     'cmodel_dev_flux_flux'->'cmodel_dev_flux'
#     'cmodel_dev_flux_fluxSigma'->'cmodel_dev_flux_err'
#     'cmodel_exp_flags'->'cmodel_exp_flag'
#     'cmodel_exp_flux_apcorr_flux'->'cmodel_exp_flux_apcorr'
#     'cmodel_exp_flux_apcorr_fluxSigma'->'cmodel_exp_flux_apcorr_err'
#     'cmodel_exp_flux_flags'->'cmodel_exp_flux_flag'
#     'cmodel_exp_flux_flux'->'cmodel_exp_flux'
#     'cmodel_exp_flux_fluxSigma'->'cmodel_exp_flux_err'
#     'cmodel_flags'->'cmodel_flag'
#     'cmodel_flux_apcorr_flux'->'cmodel_flux_apcorr'
#     'cmodel_flux_apcorr_fluxSigma'->'cmodel_flux_apcorr_err'
#     'cmodel_flux_flags'->'cmodel_flux_flag'
#     'cmodel_flux_flux'->'cmodel_flux'
#     'cmodel_flux_fluxSigma'->'cmodel_flux_err'
#     'cmodel_initial_flags'->'cmodel_initial_flag'
#     'cmodel_initial_flux_flags'->'cmodel_initial_flux_flag'
#     'cmodel_initial_flux_flux'->'cmodel_initial_flux'
#     'cmodel_initial_flux_fluxSigma'->'cmodel_initial_flux_err'
#     'deblend_has_stray_flux_flux'->'deblend_has_stray_flux'
#     'deblend_psf-flux_flux'->'deblend_psf-flux'
#     'flags'->'flag'
#     'flux_aperture_flags'->'flux_aperture_flag'
#     'flux_aperture_flux'->'flux_aperture'
#     'flux_aperture_fluxSigma'->'flux_aperture_err'
#     'flux_aperture_nInterpolatedPixel_flux'->'flux_aperture_nInterpolatedPixel'
#     'flux_aperture_nProfile_flux'->'flux_aperture_nProfile'
#     'flux_gaussian_apcorr_flux'->'flux_gaussian_apcorr'
#     'flux_gaussian_apcorr_fluxSigma'->'flux_gaussian_apcorr_err'
#     'flux_gaussian_flags'->'flux_gaussian_flag'
#     'flux_gaussian_flux'->'flux_gaussian'
#     'flux_gaussian_fluxSigma'->'flux_gaussian_err'
#     'flux_kron_apcorr_flux'->'flux_kron_apcorr'
#     'flux_kron_apcorr_fluxSigma'->'flux_kron_apcorr_err'
#     'flux_kron_flags'->'flux_kron_flag'
#     'flux_kron_flux'->'flux_kron'
#     'flux_kron_fluxSigma'->'flux_kron_err'
#     'flux_kron_psfRadius_flux'->'flux_kron_psfRadius'
#     'flux_kron_radiusForRadius_flux'->'flux_kron_radiusForRadius'
#     'flux_kron_radius_flux'->'flux_kron_radius'
#     'flux_naive_flags'->'flux_naive_flag'
#     'flux_naive_flux'->'flux_naive'
#     'flux_naive_fluxSigma'->'flux_naive_err'
#     'flux_psf_apcorr_flux'->'flux_psf_apcorr'
#     'flux_psf_apcorr_fluxSigma'->'flux_psf_apcorr_err'
#     'flux_psf_flags'->'flux_psf_flag'
#     'flux_psf_flux'->'flux_psf'
#     'flux_psf_fluxSigma'->'flux_psf_err'
#     'flux_sinc_flags'->'flux_sinc_flag'
#     'flux_sinc_flux'->'flux_sinc'
#     'flux_sinc_fluxSigma'->'flux_sinc_err'
#     'multishapelet_psf_flags'->'multishapelet_psf_flag'
#     'shape_hsm_moments_centroid_flags'->'shape_hsm_moments_centroid_flag'
#     'shape_hsm_moments_centroid_xSigma'->'shape_hsm_moments_centroid_err_xSigma'
#     'shape_hsm_moments_centroid_x_y_Cov'->'shape_hsm_moments_centroid_err_x_y_Cov'
#     'shape_hsm_moments_centroid_ySigma'->'shape_hsm_moments_centroid_err_ySigma'
#     'shape_hsm_moments_flags'->'shape_hsm_moments_flag'
#     'shape_hsm_moments_xxSigma'->'shape_hsm_moments_err_xxSigma'
#     'shape_hsm_moments_xx_xy_Cov'->'shape_hsm_moments_err_xx_xy_Cov'
#     'shape_hsm_moments_xx_yy_Cov'->'shape_hsm_moments_err_xx_yy_Cov'
#     'shape_hsm_moments_xySigma'->'shape_hsm_moments_err_xySigma'
#     'shape_hsm_moments_yySigma'->'shape_hsm_moments_err_yySigma'
#     'shape_hsm_moments_yy_xy_Cov'->'shape_hsm_moments_err_yy_xy_Cov'
#     'shape_hsm_psfMoments_centroid_flags'->'shape_hsm_psfMoments_centroid_flag'
#     'shape_hsm_psfMoments_centroid_xSigma'->'shape_hsm_psfMoments_centroid_err_xSigma'
#     'shape_hsm_psfMoments_centroid_x_y_Cov'->'shape_hsm_psfMoments_centroid_err_x_y_Cov'
#     'shape_hsm_psfMoments_centroid_ySigma'->'shape_hsm_psfMoments_centroid_err_ySigma'
#     'shape_hsm_psfMoments_flags'->'shape_hsm_psfMoments_flag'
#     'shape_hsm_psfMoments_xxSigma'->'shape_hsm_psfMoments_err_xxSigma'
#     'shape_hsm_psfMoments_xx_xy_Cov'->'shape_hsm_psfMoments_err_xx_xy_Cov'
#     'shape_hsm_psfMoments_xx_yy_Cov'->'shape_hsm_psfMoments_err_xx_yy_Cov'
#     'shape_hsm_psfMoments_xySigma'->'shape_hsm_psfMoments_err_xySigma'
#     'shape_hsm_psfMoments_yySigma'->'shape_hsm_psfMoments_err_yySigma'
#     'shape_hsm_psfMoments_yy_xy_Cov'->'shape_hsm_psfMoments_err_yy_xy_Cov'
#     'shape_hsm_regauss_flags'->'shape_hsm_regauss_flag'
#     'shape_sdss_centroid_flags'->'shape_sdss_centroid_flag'
#     'shape_sdss_centroid_xSigma'->'shape_sdss_centroid_err_xSigma'
#     'shape_sdss_centroid_x_y_Cov'->'shape_sdss_centroid_err_x_y_Cov'
#     'shape_sdss_centroid_ySigma'->'shape_sdss_centroid_err_ySigma'
#     'shape_sdss_flags'->'shape_sdss_flag'
#     'shape_sdss_xxSigma'->'shape_sdss_err_xxSigma'
#     'shape_sdss_xx_xy_Cov'->'shape_sdss_err_xx_xy_Cov'
#     'shape_sdss_xx_yy_Cov'->'shape_sdss_err_xx_yy_Cov'
#     'shape_sdss_xySigma'->'shape_sdss_err_xySigma'
#     'shape_sdss_yySigma'->'shape_sdss_err_yySigma'
#     'shape_sdss_yy_xy_Cov'->'shape_sdss_err_yy_xy_Cov'
#     'slot_ApFlux'->'flux_sinc'
#     'slot_Centroid'->'centroid_sdss'
#     'slot_InstFlux'->'flux_naive'
#     'slot_ModelFlux'->'cmodel_flux'
#     'slot_PsfFlux'->'flux_psf'
#     'slot_Shape'->'shape_hsm_moments'
# )

# %% [markdown]
# ### Field Names
#
# First off, you'll note that it seems we've translated periods to underscores.  In fact, all we really did was *not* translate underscores to periods when reading; if we look at the raw form of the original file, we actually saved all those periods as underscores:

# %%
import pyfits
fits = pyfits.open("empty-v0.fits")
print fits[1].header["ttype5"]
# Out:
# deblend_nchild

# %% [markdown]
# This translation was due to me misinterpreting a recommendation in the FITS standard about sticking to lowercase letters, numbers, and underscores in field names as a requirement.  Of course, we're still mostly in line with that recommendation, though we do use capital letters now too (and none of this is mandated by the code - these are all just conventions).
#
# We haven't tried here to create camelCase field names that look like the ones the measurement framework produces now.  That would probably still be confusing, since the resulting names wouldn't actually be in use in either the old codebase or the new one.  And it's not really possible to do automatically anyway, since we conflated namespace separation with word separation in the old conventions.

# %% [markdown]
# ### Compound Fields to FunctorKeys
#
# We've also removed all the compound fields, replacing them with the scalar fields that comprise them (e.g. two `Angle` fields instead of a `Coord` field).  Those compound field types have now been completely removed from `afw`, with a new `FunctorKey` system to replace them.  `FunctorKey`s are subclasses of `InputFunctorKey` and/or `OutputFunctorKey`, and they're really just a simple callback mechanism: when you pass a `FunctorKey` to a `Record` instead of a regular `Key`, it just calls the `get` or `set` method on the `FunctorKey` and returns the result.  Most `FunctorKey`s simply hold a few regular `Key`s and use them to pack or unpack scalar values into first-class objects.  `FunctorKey`s have a few advantages over the old compound keys:
#  - There's no hard limit on the number of types of `FunctorKey`s we can support (there is a limit on the number of intrinsic types, imposed by Boost.Variant).
#  - `FunctorKey`s can be defined in any package (intrinsic types must be defined in `afw.table`).
#  - Only the constituent scalar field can be extracted as column arrays in either approach, but with `FunctorKey`s these are what appear when printing or otherwise introspecting the `Schema`; with the old compound fields users were frequently confused by the fact that these fields could not be accessed as column arrays, and the workaround (accessing subfields of the compound fields) was not at all intuitive.
#  - `FunctorKey`s can do more than just aggregate fields: we could also use them to do calculations.  For instance, one could hold a `Calib` and convert fluxes to magnitudes on-the-fly.  (At present, all `FunctorKey`s are aggregates, though `CovarianceMatrixKey` does some squares and square-roots to produce matrices from stored sigma values and vice versa).
#
# ### Aliases, Slots, and Naming Conventions
#
# At the bottom of the `Schema`, we can see some alias definitions.  These are how slots are now defined, but we're using them for more than that here: we've created aliases to convert between some of the old conventions and the new ones.
#
# In the old conventions, algorithms had the following fields:
#  - `"<algorithm-name>"`
#  - `"<algorithm-name>.err"`
#  - `"<algorithm-name>.flags"`
# They typically also had `"<algorithm-name>.flag.<problem>"` fields to indicate specific failure modes.  For flux algorithms, the first two fields were scalars holding the flux and its 1-sigma uncertainty.  For centroids (and shapes) the first field was a `PointD` (`MomentsD`) field and the uncertainty a `CovPointF` (`CovMomentsF`).  This convention couldn't really handle algorithms that produced more than one kind of result, and the fact that the `Flag` field had a plural name was confusing.
#
# In the new conventions, field names start with the algorithm name (which is now CamelCase with a prefix indicating the package, e.g. `"base_SdssCentroid"`), and have suffixes for different kinds of measurements:
#  - `"<algorithm-name>_flux"`
#  - `"<algorithm-name>_x"`, `"<algorithm-name>_y"`
# Uncertainties are handled by the `CovarianceMatrixKey` `FunctorKey`, which aggregates fields that match the conventions specified in the LSST database schema, e.g.:
#  - `"<algorithm-name>_fluxSigma"`
#  - `"<algorithm-name>_xSigma"`, `"<algorithm-name>_ySigma"`, `"<algorithm-name>_x_y_Cov"`
# These naturally handle algorithms with more than one kind of result, and they make it easier to get uncertainties on individual scalar components as well.  We've also removed the `"s"` from the main flag field:
#  - `"<algorithm-name>_flag"` (with `"<algorithm-name>_flag_<probem>"` optional).
# Note that the new conventions often lead to names with some duplication, e.g. `"base_PsfFlux_flux"`, but I think that's a price worth paying from consistency and predictability.
#
# We've partially renamed some of those fields to match thew new conventions when it was required to convert from a compound field to a `FunctorKey` (mostly the case for the covariance matrices).  But instead of renaming the rest, we've created aliases that map any field that obeyed the old conventions to the new ones.  Crucially, that lets the algorithms be used in the slot mechanism, which relies on the suffix conventions to provide consistent access to different algorithms.  You can see the slots in the last few aliases in the file; we simply alias the algorithm name to the slot definition name, and because aliases are resolved recursively, we can get from the expected fields names in the new conventions to the actual field names being used.

# %% [markdown]
# ### Versioning
#
# Before the changes on DM-1766, we supported both the new-style `Schema`s and the old ones, using an integer version number attached to the `Schema` object, and a lot of special-case code all over the pipeline (version=0 indicated the old version, version=1 is the new).  That in-memory version number has now been removed, and all tables and now written as version 1.  When we detect a version 0 table on disk (either because it's explicitly saved as version 0, or if it has no version number *and* it has a tag indicating it was written by `afw.table`), we apply all of the above conversions, and it becomes a version 1 table in memory.
